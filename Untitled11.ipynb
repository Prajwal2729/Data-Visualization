# %%
import pandas as pd
df=pd.read_csv('/content/train/train (2).csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
agemean=df['Age'].mean()

# %%
df['Age']=df['Age'].fillna(agemean)

# %%
df.tail(4)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex        Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 887  female  19.000000      0      0      112053  30.00   B42        S
# 888  female  29.699118      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.000000      0      0      111369  30.00  C148        C
# 890    male  32.000000      0      0      370376   7.75   NaN        Q

# %%
df.drop('Cabin',axis=1,inplace=True)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
filtered_age=df[df.Age>40]
filtered_age
# Out:
#      PassengerId  Survived  Pclass  \
# 6              7         0       1
# 11            12         1       1
# 15            16         1       2
# 33            34         0       2
# 35            36         0       1
# ..           ...       ...     ...
# 862          863         1       1
# 865          866         1       2
# 871          872         1       1
# 873          874         0       3
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 33                               Wheadon, Mr. Edward H    male  66.0      0
# 35                      Holverson, Mr. Alexander Oskar    male  42.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
sorted_pass=df.sort_values('Name',ascending=True,kind='heapsort')
sorted_pass.head(20)
# Out:
#      PassengerId  Survived  Pclass  \
# 845          846         0       3
# 746          747         0       3
# 279          280         1       3
# 308          309         0       2
# 874          875         1       2
# 365          366         0       3
# 401          402         0       3
# 40            41         0       3
# 855          856         1       3
# 207          208         1       3
# 810          811         0       3
# 840          841         0       3
# 210          211         0       3
# 784          785         0       3
# 730          731         1       1
# 4              5         0       3
# 305          306         1       1
# 297          298         0       1
# 498          499         0       1
# 834          835         0       3
#
#                                                 Name     Sex    Age  SibSp  \
# 845                              Abbing, Mr. Anthony    male  42.00      0
# ...

# %%
merged_df=pd.merge(df.head(2),df.tail(2),how='outer',indicator=True)
merged_df
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2          890         1       1
# 3          891         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Behr, Mr. Karl Howell    male  26.0      0
# 3                                Dooley, Mr. Patrick    male  32.0      0
#
#    Parch     Ticket     Fare Embarked      _merge
# 0      0  A/5 21171   7.2500        S   left_only
# 1      0   PC 17599  71.2833        C   left_only
# 2      0     111369  30.0000        C  right_only
# 3      0     370376   7.7500        Q  right_only

# %%
group_df=df.groupby('Name')
for key,item in group_df:
  print(group_df.get_group(key),"\n\n")
# Out:
# Streaming output truncated to the last 5000 lines.
#      Parch      Ticket  Fare Embarked
# 671      0  F.C. 12750  52.0        S
#
#
#      PassengerId  Survived  Pclass                            Name   Sex  Age  \
# 549          550         1       2  Davies, Master. John Morgan Jr  male  8.0
#
#      SibSp  Parch      Ticket   Fare Embarked
# 549      1      1  C.A. 33112  36.75        S
#
#
#      PassengerId  Survived  Pclass                  Name   Sex   Age  SibSp  \
# 565          566         0       3  Davies, Mr. Alfred J  male  24.0      2
#
#      Parch     Ticket   Fare Embarked
# 565      0  A/4 48871  24.15        S
#
#
#      PassengerId  Survived  Pclass                       Name   Sex   Age  \
# 385          386         0       2  Davies, Mr. Charles Henry  male  18.0
#
#      SibSp  Parch        Ticket  Fare Embarked
# 385      0      0  S.O.C. 14879  73.5        S
#
#
#      PassengerId  Survived  Pclass               Name     Sex   Age  SibSp  \
# ...

# %%
group_df=df.groupby('PassengerId')
for key,item in group_df:
  print(group_df.get_group(key),"\n\n")
# Out:
# Streaming output truncated to the last 5000 lines.
#
#      PassengerId  Survived  Pclass                  Name   Sex   Age  SibSp  \
# 203          204         0       3  Youseff, Mr. Gerious  male  45.5      0
#
#      Parch Ticket   Fare Embarked
# 203      0   2628  7.225        C
#
#
#      PassengerId  Survived  Pclass                      Name   Sex   Age  \
# 204          205         1       3  Cohen, Mr. Gurshon "Gus"  male  18.0
#
#      SibSp  Parch    Ticket  Fare Embarked
# 204      0      0  A/5 3540  8.05        S
#
#
#      PassengerId  Survived  Pclass                        Name     Sex  Age  \
# 205          206         0       3  Strom, Miss. Telma Matilda  female  2.0
#
#      SibSp  Parch  Ticket     Fare Embarked
# 205      0      1  347054  10.4625        S
#
#
#      PassengerId  Survived  Pclass                        Name   Sex   Age  \
# 206          207         0       3  Backstrom, Mr. Karl Alfred  male  32.0
#
# ...
